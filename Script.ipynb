# %% [markdown]
# <a href="https://colab.research.google.com/github/titouanlegrand21/IAE_METZ_DATA_AUDIT/blob/main/Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cours action sanofi

# %%
import pandas as pd
from google.colab import files

# Charger le fichier depuis ton PC
uploaded = files.upload()

# Lire le fichier Excel (et non CSV) en accédant au contenu du dictionnaire 'uploaded'
import io
train_df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

train_df.head()
train_df.info()
# Out:
#      <input type="file" id="files-44a8f71b-5d69-48e8-8dda-efc321f0e556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44a8f71b-5d69-48e8-8dda-efc321f0e556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    61 non-null     datetime64[ns]
#  1   Price   61 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
train_df.describe()
# Out:
#                                 Date       Price
# count                             61   61.000000
# mean   2021-07-29 23:12:47.213114880   86.587302
# min              2019-01-31 00:00:00   71.847466
# 25%              2020-04-30 00:00:00   82.180000
# 50%              2021-07-30 00:00:00   86.480000
# 75%              2022-10-31 00:00:00   89.840000
# max              2023-12-29 00:00:00  101.480000
# std                              NaN    7.550186

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Lecture du fichier
df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

# Conversion de la date
df["Date"] = pd.to_datetime(df["Date"])

# Graphique simple
plt.plot(df["Date"], df["Price"])
plt.xlabel("Date")
plt.ylabel("Cours")
plt.title("Cours de l'action Sanofi")
plt.show()

# %% [markdown]
# brevet déposé

# %%
import pandas as pd
from google.colab import files

# Charger le fichier depuis ton PC
uploaded = files.upload()

# Lire le fichier Excel (et non CSV) en accédant au contenu du dictionnaire 'uploaded'
import io
train_df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

train_df.head()
train_df.info()
# Out:
#      <input type="file" id="files-32f65eb2-0d7d-4c06-8994-ac05c358a638" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32f65eb2-0d7d-4c06-8994-ac05c358a638">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    6 non-null      datetime64[ns]
#  1   nombre_brevets_déposés  6 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 228.0 bytes

# %%
train_df.describe()
# Out:
#                       date  nombre_brevets_déposés
# count                    6                6.000000
# mean   2021-07-02 04:00:00              108.000000
# min    2019-01-01 00:00:00               93.000000
# 25%    2020-04-01 12:00:00              100.500000
# 50%    2021-07-02 12:00:00              105.000000
# 75%    2022-10-01 18:00:00              117.750000
# max    2024-01-01 00:00:00              124.000000
# std                    NaN               12.247449

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Lecture du fichier
df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

# Conversion de la date
df["date"] = pd.to_datetime(df["date"])

import pandas as pd
import matplotlib.pyplot as plt

# Exemple de ton vrai DataFrame
df = pd.DataFrame({
    'date': ['2019-01-01', '2020-01-01', '2021-01-01','2022-01-01','2023-01-01','2024-01-01'],
    'nb_brevets': [100, 93, 121,108,102,124]
})

# Extraire l'année
df['annee'] = pd.to_datetime(df['date']).dt.year

# Figure
plt.figure(figsize=(10,6))

# Barres
plt.bar(df['annee'], df['nb_brevets'], color='skyblue')

# Ajouter les valeurs au-dessus des barres
for i, v in enumerate(df['nb_brevets']):
    plt.text(df['annee'][i], v + 2, str(v), ha='center', va='bottom')

plt.xlabel("Année")
plt.ylabel("Nombre de brevets déposés")
plt.title("Nombre de brevets déposés par année")
plt.ylim(0, max(df['nb_brevets']) + 20)

plt.show()

# %% [markdown]
# Essai clinique sanofi

# %%
import pandas as pd
from google.colab import files

# Charger le fichier depuis ton PC
uploaded = files.upload()

# Lire le fichier Excel (et non CSV) en accédant au contenu du dictionnaire 'uploaded'
import io
train_df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

train_df.head()
train_df.info()
# Out:
#      <input type="file" id="files-e3d8535a-a673-4e28-8940-9b920aa051a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3d8535a-a673-4e28-8940-9b920aa051a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    67 non-null     object
#  1   statut  67 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io
# Charger le fichier Excel
df = pd.read_excel(io.BytesIO(next(iter(uploaded.values()))))

# Nettoyer les noms de colonnes : enlever espaces et mettre en minuscule
df.columns = df.columns.str.strip().str.lower()
print("Colonne utilisée pour la date :", date_col)
df["date"] = pd.to_datetime(df["date"])

# Graphique
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='date', hue=statut_col, palette="Set2")
plt.xlabel("Année")
plt.ylabel("Nombre d'essais")
plt.title("Répartition des essais cliniques Sanofi par année et statut")
plt.legend(title="Statut")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Colonne utilisée pour la date : date

# %% [markdown]
# matrice correlation
